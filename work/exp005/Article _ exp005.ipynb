# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import time
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm import tqdm
import math
from sklearn.model_selection import train_test_split,StratifiedKFold
from sklearn import metrics
import re
import random

import tensorflow as tf
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, CuDNNGRU, Conv1D
from keras.layers import Bidirectional, GlobalMaxPool1D
from keras.models import Model
from keras.models import load_model
from keras import initializers, regularizers, constraints, optimizers, layers
import torch


seed = 42
n_folds = 5

random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
import os

DIR = "/content/drive/MyDrive/Competitions/probspace/研究論文の国際学会採択予測"
INPUT_DIR = os.path.join(DIR,"input")
OUTPUT_DIR = os.path.join(DIR,"output")

if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# %%
class CFG:
  debug=False
  ver=5
  seed=42
  model="GRU"
  n_folds = 15
  target_col="y"

# %%
import pandas as pd
import numpy as np

train = pd.read_csv(os.path.join(INPUT_DIR,"train_data.csv"))
test = pd.read_csv(os.path.join(INPUT_DIR,"test_data.csv"))
sample_sub = pd.read_csv(os.path.join(INPUT_DIR,"submission.csv"))

train["src"]="train"
test["src"]="test"

df = pd.concat([train,test],ignore_index=True)

print(train.shape)
display(train.head(3))

print(test.shape)
display(test.head(3))

print(sample_sub.shape)
display(sample_sub.head(3))
# Out:
# (4974, 7)
#    id                                             title  year  \
# 0   1      Hierarchical Adversarially Learned Inference  2018
# 1   2    Learning to Compute Word Embeddings On the Fly  2018
# 2   3  Graph2Seq: Scalable Learning Dynamics for Graphs  2018
#
#                                             abstract  \
# 0  We propose a novel hierarchical generative mod...
# 1  Words in natural language follow a Zipfian dis...
# 2  Neural networks are increasingly used as a gen...
#
#                                             keywords  y    src
# 0  generative, hierarchical, unsupervised, semisu...  0  train
# 1      NLU, word embeddings, representation learning  0  train
# 2                                                NaN  0  train
# (6393, 6)
#    id                                              title  year  \
# 0   1  StyleAlign: Analysis and Applications of Align...  2022
# 1   2  Embedding a random graph via GNN: mean-field i...  2021
# 2   3  BBRefinement: an universal scheme to improve p...  2021
#
#                                             abstract  \
# 0  In this paper, we perform an in-depth study of...
# 1  We develop a theory for embedding a random gra...
# 2  We present a conceptually simple yet powerful ...
#
#                                             keywords   src
# 0  StyleGAN, transfer learning, fine tuning, mode...  test
# 1  Graph neural network, graph embedding, multi-r...  test
# 2  object detection, deep neural networks, refine...  test
# (6393, 2)
#    id  y
# 0   1  0
# 1   2  0
# 2   3  0

# %%
#train["full_text"] = train["title"] + " " + train["abstract"]
#test["full_text"] = test["title"] + " " + test["abstract"]

train["full_text"] = train["abstract"]
test["full_text"] = test["abstract"]

# %%
if CFG.debug:
  print(train.shape)
  print(test.shape)
  train = train.sample(n=500, random_state=CFG.seed).reset_index(drop=True)
  test = test.sample(n=500, random_state=CFG.seed).reset_index(drop=True)
  print(train.shape)
  print(test.shape)

# %%
from sklearn.model_selection import StratifiedKFold, StratifiedGroupKFold
skf = StratifiedKFold(n_splits=CFG.n_folds, shuffle=True, random_state=CFG.seed)
for i,(train_index, val_index) in enumerate(skf.split(train,train[CFG.target_col])):
    train.loc[val_index,'fold'] = i

print('Train samples per fold:')
train["fold"] = train["fold"].astype(int)
display(train.groupby("fold").size())
# Out:
# Train samples per fold:
# fold
# 0     332
# 1     332
# 2     332
# 3     332
# 4     332
# 5     332
# 6     332
# 7     332
# 8     332
# 9     331
# 10    331
# 11    331
# 12    331
# 13    331
# 14    331
# dtype: int64

# %%
## some config values 
embed_size = 300 # how big is each word vector
max_features = 50000 # how many unique words to use (i.e num rows in embedding vector)
maxlen = 100 # max number of words in a question to use

oof_df = pd.DataFrame()
preds = np.zeros((len(test),1))
for fold in range(CFG.n_folds):
  print("="*10+f" fold = {fold} "+"="*10)

  train_df = train.loc[train.fold!=fold]
  val_df = train.loc[train.fold==fold]

  ## fill up the missing values
  train_X = train_df["full_text"].fillna("_na_").values
  val_X = val_df["full_text"].fillna("_na_").values
  test_X = test["full_text"].fillna("_na_").values

  ## Tokenize the sentences
  tokenizer = Tokenizer(num_words=max_features)
  tokenizer.fit_on_texts(list(train_X))
  train_X = tokenizer.texts_to_sequences(train_X)
  val_X = tokenizer.texts_to_sequences(val_X)
  test_X = tokenizer.texts_to_sequences(test_X)

  ## Pad the sentences 
  train_X = pad_sequences(train_X, maxlen=maxlen)
  val_X = pad_sequences(val_X, maxlen=maxlen)
  test_X = pad_sequences(test_X, maxlen=maxlen)

  ## Get the target values
  train_y = train_df['y'].values
  val_y = val_df['y'].values

  inp = Input(shape=(maxlen,))
  x = Embedding(max_features, embed_size)(inp)
  x = Bidirectional(CuDNNGRU(64, return_sequences=True))(x)
  x = GlobalMaxPool1D()(x)
  x = Dense(16, activation="relu")(x)
  x = Dropout(0.1)(x)
  x = Dense(1, activation="sigmoid")(x)
  model = Model(inputs=inp, outputs=x)
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

  model.fit(train_X, train_y, batch_size=512, epochs=3, validation_data=(val_X, val_y))

  pred_noemb_val_y = model.predict([val_X], batch_size=1024, verbose=1)
  pred_noemb_test_y = model.predict([test_X], batch_size=1024, verbose=1)

  val_df['pred_values'] = pred_noemb_val_y
  preds+=pred_noemb_test_y

  oof_df = pd.concat([oof_df, val_df])

  #model.save(OUTPUT_MODEL_DIR+f'GRU_model_fold{fold}.h5')

  del model,train_df,val_df,train_X,val_X,test_X,pred_noemb_val_y,pred_noemb_test_y
# Out:
# ========== fold = 0 ==========
# Epoch 1/3
# 10/10 [==============================] - 11s 324ms/step - loss: 0.6722 - accuracy: 0.6249 - val_loss: 0.6336 - val_accuracy: 0.6958
# Epoch 2/3
# 10/10 [==============================] - 2s 235ms/step - loss: 0.6194 - accuracy: 0.6937 - val_loss: 0.6161 - val_accuracy: 0.6958
# Epoch 3/3
# 10/10 [==============================] - 2s 184ms/step - loss: 0.6107 - accuracy: 0.6937 - val_loss: 0.6137 - val_accuracy: 0.6958
# 1/1 [==============================] - 0s 239ms/step
# 7/7 [==============================] - 1s 46ms/step
# ========== fold = 1 ==========
# <ipython-input-9-91c0f210496e>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df['pred_values'] = pred_noemb_val_y
# Epoch 1/3
# 10/10 [==============================] - 6s 265ms/step - loss: 0.6814 - accuracy: 0.6032 - val_loss: 0.6522 - val_accuracy: 0.6928
# Epoch 2/3
# 10/10 [==============================] - 2s 167ms/step - loss: 0.6348 - accuracy: 0.6941 - val_loss: 0.6187 - val_accuracy: 0.6928
# Epoch 3/3
# 10/10 [==============================] - 2s 174ms/step - loss: 0.6119 - accuracy: 0.6935 - val_loss: 0.6170 - val_accuracy: 0.6928
# 1/1 [==============================] - 0s 204ms/step
# 7/7 [==============================] - 0s 28ms/step
# ========== fold = 2 ==========
# Epoch 1/3
# 10/10 [==============================] - 5s 256ms/step - loss: 0.6616 - accuracy: 0.6288 - val_loss: 0.6198 - val_accuracy: 0.6928
# Epoch 2/3
# 10/10 [==============================] - 2s 256ms/step - loss: 0.6152 - accuracy: 0.6939 - val_loss: 0.6176 - val_accuracy: 0.6928
# Epoch 3/3
# 10/10 [==============================] - 2s 171ms/step - loss: 0.6050 - accuracy: 0.6939 - val_loss: 0.6101 - val_accuracy: 0.6928
# 1/1 [==============================] - 0s 214ms/step
# 7/7 [==============================] - 0s 28ms/step
# ========== fold = 3 ==========
# Epoch 1/3
# 10/10 [==============================] - 5s 292ms/step - loss: 0.6693 - accuracy: 0.6387 - val_loss: 0.6303 - val_accuracy: 0.6928
# Epoch 2/3
# 10/10 [==============================] - 2s 198ms/step - loss: 0.6185 - accuracy: 0.6939 - val_loss: 0.6166 - val_accuracy: 0.6928
# Epoch 3/3
# 10/10 [==============================] - 2s 152ms/step - loss: 0.6090 - accuracy: 0.6939 - val_loss: 0.6133 - val_accuracy: 0.6928
# 1/1 [==============================] - 0s 210ms/step
# 7/7 [==============================] - 0s 25ms/step
# ========== fold = 4 ==========
# Epoch 1/3
# 10/10 [==============================] - ETA: 0s - loss: 0.6647 - accuracy: 0.6512
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7f387c682040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 10/10 [==============================] - 4s 211ms/step - loss: 0.6647 - accuracy: 0.6512 - val_loss: 0.6239 - val_accuracy: 0.6928
# Epoch 2/3
# 10/10 [==============================] - 2s 213ms/step - loss: 0.6148 - accuracy: 0.6939 - val_loss: 0.6195 - val_accuracy: 0.6928
# Epoch 3/3
# 10/10 [==============================] - 2s 236ms/step - loss: 0.6031 - accuracy: 0.6939 - val_loss: 0.6115 - val_accuracy: 0.6928
# 1/1 [==============================] - 0s 204ms/step
# 7/7 [==============================] - 0s 26ms/step
# ========== fold = 5 ==========
# Epoch 1/3
# 10/10 [==============================] - ETA: 0s - loss: 0.6452 - accuracy: 0.6937
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7f3889d6bf70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 10/10 [==============================] - 4s 188ms/step - loss: 0.6452 - accuracy: 0.6937 - val_loss: 0.6162 - val_accuracy: 0.6928
# Epoch 2/3
# 10/10 [==============================] - 2s 153ms/step - loss: 0.6113 - accuracy: 0.6939 - val_loss: 0.6157 - val_accuracy: 0.6928
# Epoch 3/3
# 10/10 [==============================] - 1s 145ms/step - loss: 0.5978 - accuracy: 0.6939 - val_loss: 0.6114 - val_accuracy: 0.6928
# 1/1 [==============================] - 0s 316ms/step
# 7/7 [==============================] - 0s 24ms/step
# ========== fold = 6 ==========
# Epoch 1/3
# 10/10 [==============================] - 4s 171ms/step - loss: 0.6509 - accuracy: 0.6695 - val_loss: 0.6160 - val_accuracy: 0.6928
# Epoch 2/3
# 10/10 [==============================] - 2s 160ms/step - loss: 0.6167 - accuracy: 0.6939 - val_loss: 0.6164 - val_accuracy: 0.6928
# Epoch 3/3
# 10/10 [==============================] - 1s 131ms/step - loss: 0.6035 - accuracy: 0.6939 - val_loss: 0.6106 - val_accuracy: 0.6928
# 1/1 [==============================] - 0s 190ms/step
# 7/7 [==============================] - 0s 23ms/step
# ========== fold = 7 ==========
# Epoch 1/3
# 10/10 [==============================] - 5s 218ms/step - loss: 0.6601 - accuracy: 0.6480 - val_loss: 0.6176 - val_accuracy: 0.6928
# Epoch 2/3
# 10/10 [==============================] - 2s 150ms/step - loss: 0.6148 - accuracy: 0.6939 - val_loss: 0.6176 - val_accuracy: 0.6928
# Epoch 3/3
# 10/10 [==============================] - 1s 133ms/step - loss: 0.6012 - accuracy: 0.6939 - val_loss: 0.6104 - val_accuracy: 0.6928
# 1/1 [==============================] - 0s 200ms/step
# 7/7 [==============================] - 0s 24ms/step
# ========== fold = 8 ==========
# Epoch 1/3
# 10/10 [==============================] - 5s 253ms/step - loss: 0.6442 - accuracy: 0.6932 - val_loss: 0.6186 - val_accuracy: 0.6928
# Epoch 2/3
# 10/10 [==============================] - 2s 205ms/step - loss: 0.6152 - accuracy: 0.6939 - val_loss: 0.6197 - val_accuracy: 0.6928
# Epoch 3/3
# 10/10 [==============================] - 2s 156ms/step - loss: 0.6063 - accuracy: 0.6939 - val_loss: 0.6159 - val_accuracy: 0.6928
# 1/1 [==============================] - 0s 203ms/step
# 7/7 [==============================] - 0s 23ms/step
# ========== fold = 9 ==========
# Epoch 1/3
# 10/10 [==============================] - 4s 216ms/step - loss: 0.6399 - accuracy: 0.6937 - val_loss: 0.6160 - val_accuracy: 0.6949
# Epoch 2/3
# 10/10 [==============================] - 1s 133ms/step - loss: 0.6129 - accuracy: 0.6937 - val_loss: 0.6144 - val_accuracy: 0.6949
# Epoch 3/3
# 10/10 [==============================] - 1s 153ms/step - loss: 0.5990 - accuracy: 0.6937 - val_loss: 0.6136 - val_accuracy: 0.6949
# 1/1 [==============================] - 0s 202ms/step
# 7/7 [==============================] - 0s 28ms/step
# ========== fold = 10 ==========
# Epoch 1/3
# 10/10 [==============================] - 4s 180ms/step - loss: 0.6727 - accuracy: 0.6427 - val_loss: 0.6397 - val_accuracy: 0.6949
# Epoch 2/3
# 10/10 [==============================] - 2s 186ms/step - loss: 0.6254 - accuracy: 0.6937 - val_loss: 0.6145 - val_accuracy: 0.6949
# Epoch 3/3
# 10/10 [==============================] - 2s 193ms/step - loss: 0.6166 - accuracy: 0.6937 - val_loss: 0.6134 - val_accuracy: 0.6949
# 1/1 [==============================] - 0s 256ms/step
# 7/7 [==============================] - 0s 26ms/step
# ========== fold = 11 ==========
# Epoch 1/3
# 10/10 [==============================] - 4s 191ms/step - loss: 0.6578 - accuracy: 0.6575 - val_loss: 0.6184 - val_accuracy: 0.6949
# Epoch 2/3
# 10/10 [==============================] - 2s 152ms/step - loss: 0.6167 - accuracy: 0.6937 - val_loss: 0.6175 - val_accuracy: 0.6949
# Epoch 3/3
# 10/10 [==============================] - 1s 134ms/step - loss: 0.6053 - accuracy: 0.6937 - val_loss: 0.6122 - val_accuracy: 0.6949
# 1/1 [==============================] - 0s 434ms/step
# 7/7 [==============================] - 0s 29ms/step
# ========== fold = 12 ==========
# Epoch 1/3
# 10/10 [==============================] - 8s 173ms/step - loss: 0.6705 - accuracy: 0.6448 - val_loss: 0.6366 - val_accuracy: 0.6949
# Epoch 2/3
# 10/10 [==============================] - 1s 124ms/step - loss: 0.6230 - accuracy: 0.6937 - val_loss: 0.6137 - val_accuracy: 0.6949
# Epoch 3/3
# 10/10 [==============================] - 1s 129ms/step - loss: 0.6130 - accuracy: 0.6937 - val_loss: 0.6119 - val_accuracy: 0.6949
# 1/1 [==============================] - 0s 206ms/step
# 7/7 [==============================] - 0s 24ms/step
# ========== fold = 13 ==========
# Epoch 1/3
# 10/10 [==============================] - 4s 162ms/step - loss: 0.6480 - accuracy: 0.6914 - val_loss: 0.6150 - val_accuracy: 0.6949
# Epoch 2/3
# 10/10 [==============================] - 2s 229ms/step - loss: 0.6148 - accuracy: 0.6937 - val_loss: 0.6165 - val_accuracy: 0.6949
# Epoch 3/3
# 10/10 [==============================] - 2s 207ms/step - loss: 0.6032 - accuracy: 0.6937 - val_loss: 0.6133 - val_accuracy: 0.6949
# 1/1 [==============================] - 0s 194ms/step
# 7/7 [==============================] - 0s 26ms/step
# ========== fold = 14 ==========
# Epoch 1/3
# 10/10 [==============================] - 4s 183ms/step - loss: 0.6450 - accuracy: 0.6935 - val_loss: 0.6132 - val_accuracy: 0.6949
# Epoch 2/3
# 10/10 [==============================] - 1s 125ms/step - loss: 0.6176 - accuracy: 0.6937 - val_loss: 0.6123 - val_accuracy: 0.6949
# Epoch 3/3
# 10/10 [==============================] - 1s 150ms/step - loss: 0.6058 - accuracy: 0.6937 - val_loss: 0.6107 - val_accuracy: 0.6949
# 1/1 [==============================] - 0s 201ms/step
# 7/7 [==============================] - 0s 28ms/step

# %%
from sklearn.metrics import accuracy_score
best_score = 0
best_thresh = 0.5
for thresh in np.arange(0.1, 0.70, 0.01):
    thresh = np.round(thresh, 2)
    score = accuracy_score(oof_df[CFG.target_col], (oof_df["pred_values"]>thresh).astype(int))
    print("Accuracy score at threshold {0} is {1}".format(thresh, score))
    if score > best_score:
      best_score = score
      best_thresh = thresh
print()
print("best Accuracy score at threshold {0} is {1}".format(best_thresh, accuracy_score(oof_df[CFG.target_col], (oof_df.pred_values>best_thresh).astype(int))))
# Out:
# Accuracy score at threshold 0.1 is 0.30619219943707277
# Accuracy score at threshold 0.11 is 0.30619219943707277
# Accuracy score at threshold 0.12 is 0.30619219943707277
# Accuracy score at threshold 0.13 is 0.30619219943707277
# Accuracy score at threshold 0.14 is 0.30619219943707277
# Accuracy score at threshold 0.15 is 0.30619219943707277
# Accuracy score at threshold 0.16 is 0.30619219943707277
# Accuracy score at threshold 0.17 is 0.30619219943707277
# Accuracy score at threshold 0.18 is 0.30619219943707277
# Accuracy score at threshold 0.19 is 0.30619219943707277
# Accuracy score at threshold 0.2 is 0.30619219943707277
# Accuracy score at threshold 0.21 is 0.30619219943707277
# Accuracy score at threshold 0.22 is 0.30619219943707277
# Accuracy score at threshold 0.23 is 0.30619219943707277
# Accuracy score at threshold 0.24 is 0.30619219943707277
# Accuracy score at threshold 0.25 is 0.30719742661841576
# Accuracy score at threshold 0.26 is 0.30900683554483316
# Accuracy score at threshold 0.27 is 0.316043425814234
# Accuracy score at threshold 0.28 is 0.3373542420587053
# Accuracy score at threshold 0.29 is 0.3761560112585444
# Accuracy score at threshold 0.3 is 0.46180136710896663
# Accuracy score at threshold 0.31 is 0.5474467229593888
# Accuracy score at threshold 0.32 is 0.6139927623642943
# Accuracy score at threshold 0.33 is 0.6568154402895054
# Accuracy score at threshold 0.34 is 0.6847607559308404
# Accuracy score at threshold 0.35 is 0.6940088459991958
# Accuracy score at threshold 0.36 is 0.6972255729794934
# Accuracy score at threshold 0.37 is 0.6952151186168074
# Accuracy score at threshold 0.38 is 0.6946119823080016
# Accuracy score at threshold 0.39 is 0.6942098914354644
# Accuracy score at threshold 0.4 is 0.6940088459991958
# Accuracy score at threshold 0.41 is 0.6940088459991958
# Accuracy score at threshold 0.42 is 0.6938078005629272
# Accuracy score at threshold 0.43 is 0.6938078005629272
# Accuracy score at threshold 0.44 is 0.6938078005629272
# Accuracy score at threshold 0.45 is 0.6938078005629272
# Accuracy score at threshold 0.46 is 0.6938078005629272
# Accuracy score at threshold 0.47 is 0.6938078005629272
# Accuracy score at threshold 0.48 is 0.6938078005629272
# Accuracy score at threshold 0.49 is 0.6938078005629272
# Accuracy score at threshold 0.5 is 0.6938078005629272
# Accuracy score at threshold 0.51 is 0.6938078005629272
# Accuracy score at threshold 0.52 is 0.6938078005629272
# Accuracy score at threshold 0.53 is 0.6938078005629272
# Accuracy score at threshold 0.54 is 0.6938078005629272
# Accuracy score at threshold 0.55 is 0.6938078005629272
# Accuracy score at threshold 0.56 is 0.6938078005629272
# Accuracy score at threshold 0.57 is 0.6938078005629272
# Accuracy score at threshold 0.58 is 0.6938078005629272
# Accuracy score at threshold 0.59 is 0.6938078005629272
# Accuracy score at threshold 0.6 is 0.6938078005629272
# Accuracy score at threshold 0.61 is 0.6938078005629272
# Accuracy score at threshold 0.62 is 0.6938078005629272
# Accuracy score at threshold 0.63 is 0.6938078005629272
# Accuracy score at threshold 0.64 is 0.6938078005629272
# Accuracy score at threshold 0.65 is 0.6938078005629272
# Accuracy score at threshold 0.66 is 0.6938078005629272
# Accuracy score at threshold 0.67 is 0.6938078005629272
# Accuracy score at threshold 0.68 is 0.6938078005629272
# Accuracy score at threshold 0.69 is 0.6938078005629272
#
# best Accuracy score at threshold 0.36 is 0.6972255729794934

# %%
test_pred = preds / CFG.n_folds
sub = test.copy()
sub[CFG.target_col] = test_pred.T[0]
sub[CFG.target_col] = (sub[CFG.target_col]>best_thresh).astype(int)


sub[["id","y"]].to_csv(os.path.join(OUTPUT_DIR, f'submit_{CFG.model}_seed{CFG.seed}_ver{CFG.ver}.csv'),index=False)
display(sub[["id","y"]])
display(sub.y.value_counts())
# Out:
#         id  y
# 0        1  0
# 1        2  0
# 2        3  0
# 3        4  0
# 4        5  0
# ...    ... ..
# 6388  6389  0
# 6389  6390  0
# 6390  6391  0
# 6391  6392  0
# 6392  6393  0
#
# [6393 rows x 2 columns]
# 0    6377
# 1      16
# Name: y, dtype: int64
